# %%
# Import python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno # for finding data gaps in matrix form
import plotly.express as px # For plotting indian map

# %%
# Reading the csv data file
data = pd.read_csv("foodDataFile.csv")

# %%
# Read top five observation on the csv file
data.head()
# Out:
#             Student_Name  Gender  Registeration Number       State  \
# 0        Nandhana Rajeev  Female            23122125.0      Kerala
# 1          Shubham kumar    Male            23122033.0       Delhi
# 2          Dhruvil patel    Male            23122118.0     Gujarat
# 3                Riya PC  Female            23122028.0      Kerala
# 4  Anushya Francisca E.P  Female            23122008.0  Tamil Nadu
#
#            Fav Food Available in Canteen Available in Market Prefered Canteen  \
# 0  Chicken Biriyani                  Yes                 Yes      MBA Canteen
# 1   Chicken biryani                  Yes                 Yes       Chopsticks
# 2    Gujarati thali                  Yes                 Yes      MBA Canteen
# 3      Kerala meals                  Yes                 Yes       Chopsticks
# 4             Pasta                  Yes                 Yes      MBA Canteen
#
#   Market/College Food  ExpenseOnFood Do have any extra source of income?  \
# ...

# %%
# For printing last 5 data rows
data.tail()
# Out:
#          Student_Name  Gender  Registeration Number          State  \
# 213     Thamizhanbu E    Male                   NaN     Tamil Nadu
# 214      Romy Rathaur  Female                   NaN  Uttar Pradesh
# 215  Sushritha Shetty  Female                   NaN      Karnataka
# 216      Amit Choubey    Male                   NaN    West Bangal
# 217     Akshita Singh  Female            23111667.0  Uttar Pradesh
#
#              Fav Food Available in Canteen Available in Market  \
# 213         Veg Thali                  Yes                  No
# 214       Paneer roti                   No                  No
# 215        Fried rice                  Yes                  No
# 216         Veg thali                  Yes                 Yes
# 217  Chappati chicken                  Yes                  No
#
#        Prefered Canteen Market/College Food  ExpenseOnFood  \
# 213         MBA Canteen              Market          14000
# 214  Cafe by the valley             College           6800
# ...

# %%
# Showing Data gaps in matrix form
msno.matrix(data)
# Out:
# <Axes: >

# %%
# its describe all the content into our csv file
print(data.describe())
# Out:
#        Registeration Number  ExpenseOnFood  StudentCount
# count          1.670000e+02     218.000000     33.000000
# mean           2.292553e+07    9005.045872      6.151515
# std            7.593598e+05    2747.973237     11.413044
# min            2.011318e+07    3000.000000      0.000000
# 25%            2.311165e+07    6800.000000      1.000000
# 50%            2.312202e+07    9000.000000      3.000000
# 75%            2.312213e+07   10000.000000      6.000000
# max            2.365234e+07   15000.000000     64.000000

# %%
# Show information about all the columns
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Student_Name                         218 non-null    object
#  1   Gender                               218 non-null    object
#  2   Registeration Number                 167 non-null    float64
#  3   State                                218 non-null    object
#  4   Fav Food                             218 non-null    object
#  5   Available in Canteen                 218 non-null    object
#  6   Available in Market                  218 non-null    object
#  7   Prefered Canteen                     218 non-null    object
#  8   Market/College Food                  218 non-null    object
#  9   ExpenseOnFood                        218 non-null    int64
#  10  Do have any extra source of income?  218 non-null    object
# ...

# %%
# showing the counts of all missing values from columns 
print("Missing values:")
print(data.isnull().sum())
# Out:
# Missing values:
# Student_Name                             0
# Gender                                   0
# Registeration Number                    51
# State                                    0
# Fav Food                                 0
# Available in Canteen                     0
# Available in Market                      0
# Prefered Canteen                         0
# Market/College Food                      0
# ExpenseOnFood                            0
# Do have any extra source of income?      0
# IndianState                            185
# StudentCount                           185
# dtype: int64

# %%
# Selecting only numeric columns for correlation analysis
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
data

# It is counting the number of males and females by readint he column 'Gender' from csv file
gender_counts = data['Gender'].value_counts()
colors = ["#0000FF", "#FF1493"] #Two colors for male and female respectivily
plt.figure(figsize=(8, 8)) #Size of the chart
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("Gender Distribution") #title
plt.axis('equal')  

plt.show() # For showing graphs

# %% [markdown]
# <h3>Insight-1 </h3> From this we can observer that there is approximately same gender distribution. There is good ratio of males and females in the college which ultimately produce a good environment.

# %%
data
# It is counting the number of diifrent elements in column "Available in Market" from csv file
gender_counts = data['Available in Market'].value_counts()

plt.figure(figsize=(8, 8)) #size of graph
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Is your preferred food available in market?") #title on chart
plt.axis('equal')  

plt.show() #printing the chart

# %% [markdown]
# <h3>Insight-2 </h3>Market provides more students with their fav food as compared to college canteen.

# %%
data
# It is counting the number ofdiffent element in column "Available in Canteen" from csv file
gender_counts = data['Available in Canteen'].value_counts()

plt.figure(figsize=(8, 8))   #size of chart
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Is your preferred food available in college canteen?")   #title
plt.axis('equal')  

plt.show() #printing graphs

# %% [markdown]
# <h3>Insight-3 </h3>College canteens are managing to provide different cuisins from across the country.

# %%
# Read the CSV file that is stored in the same directory as the source file
data = pd.read_csv('foodDataFile.csv')

# Extract the data from the "Market/College Food" column
data1 = data['Market/College Food']

# Plot the data on a pie chart cause we have ony two attribute to plot
plt.figure(figsize=(8, 8))  # Size os the pie chart
plt.pie(data1.value_counts(), labels=data1.value_counts().index, autopct='%1.1f%%', startangle=140)
plt.title("Distribution of Market/College Food") # Title for the chart
plt.show() # to show the pie chart

# %% [markdown]
# <h3>Insight-4 </h3> Student prefers market for food rather than college. However the difference is very less.

# %%
# Read the CSV file that is stored in the same directory as the source file
data = pd.read_csv('foodDataFile.csv')

# Extract the data from the "Market/College Food" column
data1 = data['Do have any extra source of income?']

# Plot the data on a pie chart cause we have ony two attribute to plot
plt.figure(figsize=(8, 8))  # Size os the pie chart
plt.pie(data1.value_counts(), labels=data1.value_counts().index, autopct='%1.1f%%', startangle=140)
plt.title("Do have any extra source of income?") # Title for the chart
plt.show() # to show the pie chart

# %% [markdown]
# <h3>Insight-5 </h3> Very less students have an extra source of income, which means they are dependent on parents for their expense.

# %%
# Distribution of runs_scored using a histogram
plt.figure(figsize=(8, 6))
sns.histplot(data['ExpenseOnFood'], bins=30, kde=True, color='skyblue')
plt.title('Expense on food')
plt.xlabel('Amount spent')
plt.ylabel('Frequency')
plt.show()

# %%
# storing the path od the csv file to a variable df as data frame
df = pd.read_csv("foodDataFile.csv")

fig = px.choropleth(
    df,
    # reading the geo json file for India map from the link
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    #for uniques identification of each Indian state
    featureidkey='properties.ST_NM',
    locations='IndianState',
    #color the state based on the count
    color='StudentCount',
    # red gredient paint
    color_continuous_scale='Reds',
)

fig.update_geos(fitbounds="locations", visible=False)

fig.show()

# %% [markdown]
# <h3>Insight-6 </h3> Kerela has the highest count of students
